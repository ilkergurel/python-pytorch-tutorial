# %%
isim = "ilker \ngürel"
print(isim)
print(isim[7])
print(isim.index("g"))

#2D list
ilker = [["i", "l", "k", "e", "r"], ["ilker"]]

ilker[-1]="ilkerr"
print(ilker[0])
print(ilker[0][2:4])
print(ilker[1][-1])
print(ilker[-1])


ilker.append(["ilker2"]) #append an item at the end

ilker.pop(1) #Remove 2nd item from the list
print(ilker)
# Out:
# ilker
# gürel
# g
# 7
# ['i', 'l', 'k', 'e', 'r']
# ['k', 'e']
# r
# ilkerr
# [['i', 'l', 'k', 'e', 'r'], ['ilker2']]

# %%
#tuples, they are immutable compared to lists
ilker=(("i","ilker1"),("l","ilker2"),("k","ilker3"),("e","ilker4"),("r","ilker5"))

print(ilker)
print(ilker[1])
print(ilker[1][1])

# ilker[1][1] = "ilker22"    #cannot perform, because tuples are immutable
# Out:
# (('i', 'ilker1'), ('l', 'ilker2'), ('k', 'ilker3'), ('e', 'ilker4'), ('r', 'ilker5'))
# ('l', 'ilker2')
# ilker2

# %%
def yapbisey(ii,jj):
    print("Bu, yapbisey fonksiyonu, toplam = ",ii+jj)


yapbisey(2,3)
# Out:
# Bu, yapbisey fonksiyonu  33
